# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_dict = {
    "City": cities,
}

city_df = pd.DataFrame(city_dict)

city_df["Country"] = ""
city_df["Lat"] = ""
city_df["Lng"] = ""
city_df["Max Temp"] = ""
city_df["Humidity"] = ""
city_df["Cloudiness"] = ""
city_df["Wind Speed"] = ""

city_df.head()
# Out:
#          City Country Lat Lng Max Temp Humidity Cloudiness Wind Speed
# 0     ushuaia
# 1    show low
# 2  hervey bay
# 3  bredasdorp
# 4     rikitea

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

query_url = f"{url}appid={api_key}&units={units}&q="
params = {
    "appid": api_key,
    "units": "metric",
    "q": name
}

for index, row in city_df.iterrows():
    
    name = row["City"]
    
    response = requests.get(query_url + name).json()
    #results = response['results']
    
    try:
        print(f"Processing record # {index} | {name}.")
        
        city_df.loc[index, "Country"] = response["sys"]["country"]
        city_df.loc[index, "Lat"] = response['coord']['lat']
        city_df.loc[index, "Lng"] = response['coord']['lon']
        city_df.loc[index, "Max Temp"] = response['main']['temp_max']
        city_df.loc[index, "Humidity"] = response['main']['humidity']
        city_df.loc[index, "Cloudiness"] = response['clouds']['all']
        city_df.loc[index, "Wind Speed"] = response['wind']['speed']
        
    except (KeyError, IndexError):
        print("City not found... skipping.")
        
    time.sleep(1)  
    
print("---------------------------")
print("Data retrieval complete")
print("---------------------------")
# Out:
# Processing record # 0 | ushuaia.
# Processing record # 1 | show low.
# Processing record # 2 | hervey bay.
# Processing record # 3 | bredasdorp.
# Processing record # 4 | rikitea.
# Processing record # 5 | kidal.
# Processing record # 6 | puerto ayora.
# Processing record # 7 | hithadhoo.
# Processing record # 8 | busselton.
# Processing record # 9 | vaini.
# Processing record # 10 | hualmay.
# Processing record # 11 | longyearbyen.
# Processing record # 12 | ponta do sol.
# Processing record # 13 | dikson.
# Processing record # 14 | ballyhaunis.
# Processing record # 15 | olafsvik.
# City not found... skipping.
# Processing record # 16 | sinaloa.
# Processing record # 17 | doka.
# Processing record # 18 | port alfred.
# Processing record # 19 | glen allen.
# Processing record # 20 | tuktoyaktuk.
# Processing record # 21 | cidreira.
# Processing record # 22 | hobart.
# Processing record # 23 | port elizabeth.
# Processing record # 24 | husavik.
# Processing record # 25 | kaitangata.
# Processing record # 26 | punta arenas.
# Processing record # 27 | ullapool.
# Processing record # 28 | illoqqortoormiut.
# City not found... skipping.
# Processing record # 29 | aykhal.
# Processing record # 30 | mys shmidta.
# City not found... skipping.
# Processing record # 31 | santa isabel do rio negro.
# Processing record # 32 | grand-lahou.
# Processing record # 33 | deputatskiy.
# Processing record # 34 | bluff.
# Processing record # 35 | zurrieq.
# Processing record # 36 | bengkulu.
# City not found... skipping.
# Processing record # 37 | castro.
# Processing record # 38 | laguna.
# Processing record # 39 | san andres.
# Processing record # 40 | sur.
# Processing record # 41 | hermanus.
# Processing record # 42 | norway.
# Processing record # 43 | alekseyevskoye.
# Processing record # 44 | padang.
# Processing record # 45 | rafiganj.
# Processing record # 46 | klaksvik.
# Processing record # 47 | hohhot.
# Processing record # 48 | shihezi.
# Processing record # 49 | saurimo.
# Processing record # 50 | urusha.
# Processing record # 51 | saleaula.
# City not found... skipping.
# Processing record # 52 | avarua.
# Processing record # 53 | makakilo city.
# Processing record # 54 | mar del plata.
# Processing record # 55 | vardo.
# Processing record # 56 | coahuayana.
# Processing record # 57 | trail.
# Processing record # 58 | harper.
# Processing record # 59 | yellowknife.
# Processing record # 60 | puerto ayacucho.
# Processing record # 61 | ahipara.
# Processing record # 62 | hobyo.
# Processing record # 63 | ercis.
# Processing record # 64 | meulaboh.
# Processing record # 65 | san policarpo.
# Processing record # 66 | sentyabrskiy.
# City not found... skipping.
# Processing record # 67 | adrar.
# Processing record # 68 | freeport.
# Processing record # 69 | lorengau.
# Processing record # 70 | souillac.
# Processing record # 71 | iqaluit.
# Processing record # 72 | darlowo.
# Processing record # 73 | purbalingga.
# Processing record # 74 | saldanha.
# Processing record # 75 | cedar city.
# Processing record # 76 | khatanga.
# Processing record # 77 | seoul.
# Processing record # 78 | katsuura.
# Processing record # 79 | hilo.
# Processing record # 80 | temir.
# Processing record # 81 | pokrovsk.
# Processing record # 82 | mataura.
# Processing record # 83 | chokurdakh.
# Processing record # 84 | homa bay.
# Processing record # 85 | albany.
# Processing record # 86 | new norfolk.
# Processing record # 87 | tasiilaq.
# Processing record # 88 | tazovskiy.
# Processing record # 89 | mayo.
# Processing record # 90 | butaritari.
# Processing record # 91 | kodiak.
# Processing record # 92 | jalu.
# Processing record # 93 | vila franca do campo.
# Processing record # 94 | oranjemund.
# Processing record # 95 | itaituba.
# Processing record # 96 | norman wells.
# Processing record # 97 | nome.
# Processing record # 98 | los llanos de aridane.
# Processing record # 99 | sao miguel.
# Processing record # 100 | atuona.
# Processing record # 101 | poum.
# Processing record # 102 | mint hill.
# Processing record # 103 | bambous virieux.
# Processing record # 104 | udachnyy.
# Processing record # 105 | ilulissat.
# Processing record # 106 | kapaa.
# Processing record # 107 | cape town.
# Processing record # 108 | arraial do cabo.
# Processing record # 109 | nikolskoye.
# Processing record # 110 | saint-augustin.
# Processing record # 111 | quatre cocos.
# Processing record # 112 | pochutla.
# Processing record # 113 | la union.
# Processing record # 114 | pangnirtung.
# Processing record # 115 | englewood.
# Processing record # 116 | alekseyevka.
# Processing record # 117 | jamestown.
# Processing record # 118 | nizhneyansk.
# City not found... skipping.
# Processing record # 119 | asau.
# City not found... skipping.
# Processing record # 120 | belushya guba.
# City not found... skipping.
# Processing record # 121 | isangel.
# Processing record # 122 | saint-philippe.
# Processing record # 123 | sitka.
# Processing record # 124 | malakal.
# City not found... skipping.
# Processing record # 125 | georgetown.
# Processing record # 126 | ancud.
# Processing record # 127 | luderitz.
# Processing record # 128 | sodertalje.
# City not found... skipping.
# Processing record # 129 | amderma.
# City not found... skipping.
# Processing record # 130 | hambantota.
# Processing record # 131 | airai.
# Processing record # 132 | arica.
# Processing record # 133 | novikovo.
# Processing record # 134 | dianopolis.
# City not found... skipping.
# Processing record # 135 | san patricio.
# Processing record # 136 | kargasok.
# Processing record # 137 | saint george.
# Processing record # 138 | barentsburg.
# City not found... skipping.
# Processing record # 139 | mitsamiouli.
# Processing record # 140 | bathsheba.
# Processing record # 141 | haapiti.
# Processing record # 142 | sao joao da barra.
# Processing record # 143 | haines junction.
# Processing record # 144 | ribeira grande.
# Processing record # 145 | lusambo.
# Processing record # 146 | taolanaro.
# City not found... skipping.
# Processing record # 147 | zhigansk.
# Processing record # 148 | upernavik.
# Processing record # 149 | fortuna.
# Processing record # 150 | gamba.
# Processing record # 151 | lebu.
# Processing record # 152 | lamar.
# Processing record # 153 | saskylakh.
# Processing record # 154 | kamenka.
# Processing record # 155 | namibe.
# Processing record # 156 | morgan city.
# Processing record # 157 | cherskiy.
# Processing record # 158 | nelson bay.
# Processing record # 159 | ennis.
# Processing record # 160 | chuy.
# Processing record # 161 | komsomolskiy.
# Processing record # 162 | payyannur.
# Processing record # 163 | victoria.
# Processing record # 164 | etchoropo.
# Processing record # 165 | nalut.
# Processing record # 166 | catamarca.
# City not found... skipping.
# Processing record # 167 | vaitupu.
# City not found... skipping.
# Processing record # 168 | fortuna foothills.
# Processing record # 169 | puerto madryn.
# Processing record # 170 | sale.
# Processing record # 171 | kavieng.
# Processing record # 172 | kavaratti.
# Processing record # 173 | florianopolis.
# Processing record # 174 | beirut.
# Processing record # 175 | east london.
# Processing record # 176 | geresk.
# City not found... skipping.
# Processing record # 177 | severo-kurilsk.
# Processing record # 178 | jibuti.
# City not found... skipping.
# Processing record # 179 | amapa.
# Processing record # 180 | lake havasu city.
# Processing record # 181 | faanui.
# Processing record # 182 | saint-georges.
# Processing record # 183 | brae.
# Processing record # 184 | rawah.
# City not found... skipping.
# Processing record # 185 | parambu.
# Processing record # 186 | nemuro.
# Processing record # 187 | barrow.
# Processing record # 188 | saint-pierre.
# Processing record # 189 | azimur.
# City not found... skipping.
# Processing record # 190 | waipawa.
# Processing record # 191 | caravelas.
# Processing record # 192 | stornoway.
# City not found... skipping.
# Processing record # 193 | chardara.
# City not found... skipping.
# Processing record # 194 | mahebourg.
# Processing record # 195 | aklavik.
# Processing record # 196 | pudozh.
# Processing record # 197 | kemijarvi.
# City not found... skipping.
# Processing record # 198 | esperance.
# Processing record # 199 | salalah.
# Processing record # 200 | clyde river.
# Processing record # 201 | dengfeng.
# Processing record # 202 | ambovombe.
# Processing record # 203 | sakakah.
# City not found... skipping.
# Processing record # 204 | tual.
# Processing record # 205 | sistranda.
# Processing record # 206 | tres arroyos.
# Processing record # 207 | rocha.
# Processing record # 208 | pemangkat.
# City not found... skipping.
# Processing record # 209 | smithers.
# Processing record # 210 | christchurch.
# Processing record # 211 | gwadar.
# Processing record # 212 | nyurba.
# Processing record # 213 | coquimbo.
# Processing record # 214 | vila velha.
# Processing record # 215 | parabel.
# Processing record # 216 | qaanaaq.
# Processing record # 217 | svetlaya.
# Processing record # 218 | port lincoln.
# Processing record # 219 | bethel.
# Processing record # 220 | port hardy.
# Processing record # 221 | rio grande.
# Processing record # 222 | kieta.
# Processing record # 223 | abeche.
# Processing record # 224 | kedougou.
# Processing record # 225 | verkhnevilyuysk.
# Processing record # 226 | codrington.
# Processing record # 227 | hasaki.
# Processing record # 228 | pentecoste.
# Processing record # 229 | suntar.
# Processing record # 230 | pisco.
# Processing record # 231 | tiksi.
# Processing record # 232 | palamos.
# Processing record # 233 | sretensk.
# Processing record # 234 | yeniseysk.
# Processing record # 235 | talcahuano.
# Processing record # 236 | roma.
# Processing record # 237 | hay river.
# Processing record # 238 | bolshoy istok.
# City not found... skipping.
# Processing record # 239 | sisimiut.
# Processing record # 240 | lompoc.
# Processing record # 241 | lagoa.
# Processing record # 242 | panaba.
# Processing record # 243 | ondjiva.
# Processing record # 244 | aswan.
# Processing record # 245 | murupara.
# Processing record # 246 | nara.
# Processing record # 247 | sao filipe.
# Processing record # 248 | verkhnyaya inta.
# Processing record # 249 | lavrentiya.
# Processing record # 250 | urubicha.
# Processing record # 251 | leshukonskoye.
# Processing record # 252 | shinuhayr.
# Processing record # 253 | grenfell.
# Processing record # 254 | ulaangom.
# Processing record # 255 | pevek.
# Processing record # 256 | butembo.
# Processing record # 257 | saint-francois.
# Processing record # 258 | virginia beach.
# Processing record # 259 | broome.
# Processing record # 260 | alegrete.
# Processing record # 261 | jumla.
# Processing record # 262 | plymouth.
# Processing record # 263 | amot.
# Processing record # 264 | doha.
# Processing record # 265 | kailua.
# Processing record # 266 | tateyama.
# Processing record # 267 | gambela.
# Processing record # 268 | khonsa.
# Processing record # 269 | bisert.
# Processing record # 270 | mwinilunga.
# Processing record # 271 | maholi.
# Processing record # 272 | uva.
# Processing record # 273 | marawi.
# Processing record # 274 | ligayan.
# Processing record # 275 | fairlie.
# Processing record # 276 | balikpapan.
# Processing record # 277 | mount isa.
# Processing record # 278 | partizanskoye.
# Processing record # 279 | sunrise manor.
# Processing record # 280 | valle nacional.
# Processing record # 281 | catemaco.
# Processing record # 282 | cuamba.
# Processing record # 283 | kahului.
# Processing record # 284 | flinders.
# Processing record # 285 | geraldton.
# Processing record # 286 | aden.
# Processing record # 287 | veraval.
# Processing record # 288 | guerrero negro.
# Processing record # 289 | mouzakion.
# City not found... skipping.
# Processing record # 290 | kruisfontein.
# Processing record # 291 | naze.
# Processing record # 292 | bandar.
# Processing record # 293 | hihifo.
# City not found... skipping.
# Processing record # 294 | uvira.
# Processing record # 295 | thompson.
# Processing record # 296 | provideniya.
# Processing record # 297 | trincomalee.
# Processing record # 298 | deder.
# Processing record # 299 | thinadhoo.
# Processing record # 300 | takoradi.
# Processing record # 301 | palmares.
# Processing record # 302 | carnarvon.
# Processing record # 303 | richards bay.
# Processing record # 304 | artyk.
# City not found... skipping.
# Processing record # 305 | wenling.
# Processing record # 306 | harrisonburg.
# Processing record # 307 | cervo.
# Processing record # 308 | kosa.
# Processing record # 309 | bouafle.
# Processing record # 310 | mendota heights.
# Processing record # 311 | laurentides.
# Processing record # 312 | nadym.
# Processing record # 313 | constitucion.
# Processing record # 314 | kudahuvadhoo.
# Processing record # 315 | havre-saint-pierre.
# Processing record # 316 | grand river south east.
# City not found... skipping.
# Processing record # 317 | maumere.
# Processing record # 318 | torbay.
# Processing record # 319 | alofi.
# Processing record # 320 | camiri.
# Processing record # 321 | tsihombe.
# City not found... skipping.
# Processing record # 322 | hun.
# Processing record # 323 | dolores.
# Processing record # 324 | sladkovo.
# Processing record # 325 | lamballe.
# Processing record # 326 | alice springs.
# Processing record # 327 | muktagachha.
# City not found... skipping.
# Processing record # 328 | astoria.
# Processing record # 329 | bilibino.
# Processing record # 330 | honiara.
# Processing record # 331 | terekli-mekteb.
# Processing record # 332 | inuvik.
# Processing record # 333 | rohru.
# Processing record # 334 | sheridan.
# Processing record # 335 | moose factory.
# Processing record # 336 | itoman.
# Processing record # 337 | tumannyy.
# City not found... skipping.
# Processing record # 338 | basco.
# Processing record # 339 | tautira.
# Processing record # 340 | weinan.
# Processing record # 341 | avera.
# Processing record # 342 | myitkyina.
# Processing record # 343 | muhos.
# Processing record # 344 | balkhash.
# Processing record # 345 | rungata.
# City not found... skipping.
# Processing record # 346 | rokytne.
# Processing record # 347 | ibra.
# Processing record # 348 | ambositra.
# Processing record # 349 | harda.
# Processing record # 350 | tiznit.
# Processing record # 351 | muyezerskiy.
# Processing record # 352 | yarada.
# Processing record # 353 | bubaque.
# Processing record # 354 | sangmelima.
# Processing record # 355 | attawapiskat.
# City not found... skipping.
# Processing record # 356 | necochea.
# Processing record # 357 | comodoro rivadavia.
# Processing record # 358 | loandjili.
# Processing record # 359 | aguimes.
# Processing record # 360 | muros.
# Processing record # 361 | houma.
# Processing record # 362 | alibag.
# Processing record # 363 | beloha.
# Processing record # 364 | anahuac.
# Processing record # 365 | rincon.
# Processing record # 366 | san quintin.
# Processing record # 367 | buraydah.
# Processing record # 368 | staraya poltavka.
# Processing record # 369 | miri.
# Processing record # 370 | bilma.
# Processing record # 371 | ixtapa.
# Processing record # 372 | lasa.
# Processing record # 373 | alvarado.
# Processing record # 374 | qianguo.
# Processing record # 375 | aflu.
# City not found... skipping.
# Processing record # 376 | novovorontsovka.
# Processing record # 377 | nishihara.
# Processing record # 378 | kragero.
# Processing record # 379 | qui nhon.
# City not found... skipping.
# Processing record # 380 | kultuk.
# Processing record # 381 | gushi.
# Processing record # 382 | diapaga.
# Processing record # 383 | peniche.
# Processing record # 384 | batemans bay.
# Processing record # 385 | leningradskiy.
# Processing record # 386 | salinas.
# Processing record # 387 | nikita.
# Processing record # 388 | hatillo.
# Processing record # 389 | luanshya.
# Processing record # 390 | tarudant.
# City not found... skipping.
# Processing record # 391 | wagar.
# Processing record # 392 | severobaykalsk.
# Processing record # 393 | astara.
# Processing record # 394 | vestmannaeyjar.
# Processing record # 395 | sindor.
# Processing record # 396 | talnakh.
# Processing record # 397 | faya.
# Processing record # 398 | causapscal.
# Processing record # 399 | yulara.
# Processing record # 400 | mollendo.
# Processing record # 401 | mursan.
# Processing record # 402 | miramar.
# Processing record # 403 | bay city.
# Processing record # 404 | tabas.
# Processing record # 405 | vangaindrano.
# Processing record # 406 | lumeje.
# Processing record # 407 | yumen.
# Processing record # 408 | hua hin.
# Processing record # 409 | bayburt.
# Processing record # 410 | bozdar.
# Processing record # 411 | byron bay.
# Processing record # 412 | the valley.
# Processing record # 413 | rypefjord.
# Processing record # 414 | todos santos.
# Processing record # 415 | batagay-alyta.
# Processing record # 416 | cockburn town.
# Processing record # 417 | vanimo.
# Processing record # 418 | hvammstangi.
# City not found... skipping.
# Processing record # 419 | hunchun.
# Processing record # 420 | broken hill.
# Processing record # 421 | marcona.
# City not found... skipping.
# Processing record # 422 | miraflores.
# Processing record # 423 | palembang.
# Processing record # 424 | blind river.
# Processing record # 425 | itanhem.
# Processing record # 426 | plettenberg bay.
# Processing record # 427 | bhindar.
# Processing record # 428 | ilanskiy.
# Processing record # 429 | hosangadi.
# Processing record # 430 | masindi.
# Processing record # 431 | gigmoto.
# Processing record # 432 | nancha.
# Processing record # 433 | lumatil.
# Processing record # 434 | cabo san lucas.
# Processing record # 435 | opuwo.
# Processing record # 436 | biu.
# Processing record # 437 | churapcha.
# Processing record # 438 | kasongo.
# Processing record # 439 | samusu.
# City not found... skipping.
# Processing record # 440 | samoded.
# Processing record # 441 | dunedin.
# Processing record # 442 | tungor.
# Processing record # 443 | san joaquin.
# Processing record # 444 | ostrovnoy.
# Processing record # 445 | pestyaki.
# Processing record # 446 | haizhou.
# Processing record # 447 | pokaran.
# Processing record # 448 | kachkanar.
# Processing record # 449 | kaspiyskiy.
# Processing record # 450 | chimoio.
# Processing record # 451 | dingle.
# Processing record # 452 | ucluelet.
# Processing record # 453 | abha.
# Processing record # 454 | beringovskiy.
# Processing record # 455 | bauchi.
# Processing record # 456 | bandarbeyla.
# Processing record # 457 | qaqortoq.
# Processing record # 458 | mount gambier.
# Processing record # 459 | healdsburg.
# Processing record # 460 | nisia floresta.
# Processing record # 461 | tessalit.
# Processing record # 462 | abu kamal.
# Processing record # 463 | srednekolymsk.
# Processing record # 464 | vrangel.
# Processing record # 465 | acapulco.
# Processing record # 466 | buenos aires.
# Processing record # 467 | port hedland.
# Processing record # 468 | cap-aux-meules.
# Processing record # 469 | dzhusaly.
# City not found... skipping.
# Processing record # 470 | madimba.
# Processing record # 471 | meliki.
# Processing record # 472 | talara.
# City not found... skipping.
# Processing record # 473 | sadovoye.
# Processing record # 474 | berlevag.
# Processing record # 475 | dubrovnik.
# Processing record # 476 | margate.
# Processing record # 477 | mubi.
# Processing record # 478 | okakarara.
# Processing record # 479 | riyadh.
# Processing record # 480 | nhulunbuy.
# Processing record # 481 | barinas.
# Processing record # 482 | jinchang.
# Processing record # 483 | beidao.
# Processing record # 484 | chernyshevskiy.
# Processing record # 485 | pointe-noire.
# Processing record # 486 | tombouctou.
# Processing record # 487 | denpasar.
# Processing record # 488 | chapais.
# Processing record # 489 | port macquarie.
# Processing record # 490 | moerai.
# Processing record # 491 | siocon.
# Processing record # 492 | macaboboni.
# City not found... skipping.
# Processing record # 493 | eyl.
# Processing record # 494 | hamilton.
# Processing record # 495 | edd.
# Processing record # 496 | bargal.
# City not found... skipping.
# Processing record # 497 | jinka.
# Processing record # 498 | nguiu.
# City not found... skipping.
# Processing record # 499 | barbar.
# City not found... skipping.
# Processing record # 500 | palmer.
# Processing record # 501 | palmaner.
# Processing record # 502 | kismayo.
# City not found... skipping.
# Processing record # 503 | merauke.
# Processing record # 504 | awjilah.
# Processing record # 505 | crestview.
# Processing record # 506 | san lazaro.
# Processing record # 507 | umzimvubu.
# City not found... skipping.
# Processing record # 508 | graaff-reinet.
# Processing record # 509 | bhabua.
# Processing record # 510 | ukiah.
# Processing record # 511 | walvis bay.
# Processing record # 512 | rabo de peixe.
# Processing record # 513 | cercal.
# Processing record # 514 | grindavik.
# Processing record # 515 | narsaq.
# Processing record # 516 | tabiauea.
# City not found... skipping.
# Processing record # 517 | palabuhanratu.
# City not found... skipping.
# Processing record # 518 | noumea.
# Processing record # 519 | tres lagoas.
# City not found... skipping.
# Processing record # 520 | thana bhawan.
# Processing record # 521 | dondo.
# Processing record # 522 | kawalu.
# Processing record # 523 | port hueneme.
# Processing record # 524 | skibbereen.
# Processing record # 525 | champerico.
# Processing record # 526 | harer.
# Processing record # 527 | te anau.
# Processing record # 528 | havoysund.
# Processing record # 529 | dandong.
# Processing record # 530 | brasilia.
# Processing record # 531 | roald.
# Processing record # 532 | sorvag.
# City not found... skipping.
# Processing record # 533 | pierre.
# Processing record # 534 | palma di montechiaro.
# Processing record # 535 | aksarka.
# Processing record # 536 | piquete.
# Processing record # 537 | darnah.
# Processing record # 538 | kulhudhuffushi.
# Processing record # 539 | kalianget.
# Processing record # 540 | norsup.
# Processing record # 541 | mansa.
# Processing record # 542 | solnechnyy.
# Processing record # 543 | carbonear.
# Processing record # 544 | independence.
# Processing record # 545 | hirara.
# Processing record # 546 | dieppe.
# Processing record # 547 | kushima.
# Processing record # 548 | bar harbor.
# Processing record # 549 | kinarut.
# Processing record # 550 | yelkhovka.
# Processing record # 551 | rajgarh.
# Processing record # 552 | guarare.
# Processing record # 553 | luanda.
# Processing record # 554 | flin flon.
# Processing record # 555 | turukhansk.
# Processing record # 556 | straumen.
# Processing record # 557 | yaan.
# Processing record # 558 | la ronge.
# Processing record # 559 | gizo.
# Processing record # 560 | liverpool.
# Processing record # 561 | garachine.
# Processing record # 562 | dalinghe.
# City not found... skipping.
# Processing record # 563 | bandrele.
# Processing record # 564 | rafai.
# Processing record # 565 | huangchuan.
# Processing record # 566 | port-gentil.
# Processing record # 567 | reoti.
# Processing record # 568 | lubango.
# Processing record # 569 | muzhi.
# Processing record # 570 | iranshahr.
# Processing record # 571 | vao.
# Processing record # 572 | lowell.
# Processing record # 573 | dalbandin.
# Processing record # 574 | tuy hoa.
# Processing record # 575 | shimoda.
# Processing record # 576 | safford.
# Processing record # 577 | inhambane.
# Processing record # 578 | zaraza.
# Processing record # 579 | rodrigues alves.
# Processing record # 580 | xique-xique.
# Processing record # 581 | zhezkazgan.
# Processing record # 582 | mazabuka.
# Processing record # 583 | marsberg.
# Processing record # 584 | juifang.
# City not found... skipping.
# Processing record # 585 | one hundred mile house.
# City not found... skipping.
# Processing record # 586 | marienburg.
# Processing record # 587 | vostok.
# Processing record # 588 | mutoko.
# Processing record # 589 | siirt.
# Processing record # 590 | bonavista.
# Processing record # 591 | pingliang.
# Processing record # 592 | ondorhaan.
# City not found... skipping.
# Processing record # 593 | mehtar lam.
# Processing record # 594 | ust-nera.
# Processing record # 595 | whitehorse.
# Processing record # 596 | bougouni.
# Processing record # 597 | buchanan.
# Processing record # 598 | port victoria.
# Processing record # 599 | tornio.
# Processing record # 600 | axim.
# Processing record # 601 | george.
# ---------------------------
# Data retrieval complete
# ---------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df.to_csv("output_data/city_data.csv")

city_df = city_df.dropna()
city_df.count()
# Out:
# City          544
# Country       544
# Lat           544
# Lng           544
# Max Temp      544
# Humidity      544
# Cloudiness    544
# Wind Speed    544
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot
plt.scatter(city_df["Lat"], city_df["Max Temp"], marker="o")

# Add title and labels
plt.title("City Latitudes vs. Max Temperatures (10/26/18)")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the plot
plt.savefig("output_data/MaxTempsinCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot
plt.scatter(city_df["Lat"], city_df["Humidity"], marker="o")

# Add title and labels
plt.title("City Latitudes vs. Humidity (10/26/18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the plot
plt.savefig("output_data/HumidityinCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot
plt.scatter(city_df["Lat"], city_df["Cloudiness"], marker="o")

# Add title and labels
plt.title("City Latitudes vs. Cloudiness (10/26/18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the plot
plt.savefig("output_data/CloudinessinCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot
plt.scatter(city_df["Lat"], city_df["Wind Speed"], marker="o")

# Add title and labels
plt.title("City Latitudes vs. Wind Speed (10/26/18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the plot
plt.savefig("output_data/WindSpeedsinCities.png")

# Show plot
plt.show()
